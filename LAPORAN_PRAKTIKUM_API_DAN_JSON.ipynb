# %%
import requests

url = "https://api.agify.io?name=budi"
response = requests.get(url)

print(response)
print(response.text)
# Out:
# <Response [200]>
# {"count":3080,"name":"budi","age":53}

# %%
import requests

url = "https://api.agify.io?name=budi"
response = requests.get(url)

data = response.json()

print(data)
print(data["name"])
print(data["age"])
# Out:
# {'count': 3080, 'name': 'budi', 'age': 53}
# budi
# 53

# %%
import requests

nama = input("Masukkan nama: ")
url = f"https://api.agify.io?name={nama}"

response = requests.get(url)
data = response.json()

print(f"Halo, {data['name']}!")
print(f"Perkiraan umur: {data['age']} tahun")
# Out:
# Masukkan nama: KHOLIS RAHMAT HABIBI
# Halo, KHOLIS RAHMAT HABIBI!
# Perkiraan umur: 53 tahun

# %%
import requests

url = "https://quotes.liupurnomo.com/api/quotes/random"
data = requests.get(url).json()

print(data["data"]["text"])
print("-", data["data"]["author"])
# Out:
# Kuasa yang didasarkan pada cinta jauh lebih efektif dan abadi dibandingkan yang berasal dari rasa takut.
# - Mahatma Gandhi

# %%
import requests

for i in range(3):
    data = requests.get( "https://quotes.liupurnomo.com/api/quotes?category=motivasi&page=1&limit=10").json()

    print(f"--- Quote ke-{i+1} ---")
    print(data["data"][i+1]["text"])
    print(f"- {data["data"][i+1]['author']}")
    print()
# Out:
# --- Quote ke-1 ---
# Siapa pun yang tidak pernah melakukan kesalahan, tidak pernah mencoba sesuatu yang baru.
# - Albert Einstein
#
# --- Quote ke-2 ---
# Jangan pernah menyerah pada impianmu. Sekecil apapun usaha yang kita lakukan, itu akan bermakna.
# - Tere Liye, Bumi
#
# --- Quote ke-3 ---
# Keberhasilan bukan tentang seberapa cepat kita mencapai tujuan, tetapi tentang seberapa konsisten kita berusaha.
# - Tere Liye, Bulan

# %%
import requests

for i in range(9):
  url = "https://quotes.liupurnomo.com/api/quotes?category=motivasi&page=1&limit=10"
  data = requests.get(url).json()
  print(f"--- Quote ke-{i+1} ---")
  print(data["data"][i+1]["text"])
  print(f"- {data["data"][i+1]['author']}")
  print()
# Out:
# --- Quote ke-1 ---
# Siapa pun yang tidak pernah melakukan kesalahan, tidak pernah mencoba sesuatu yang baru.
# - Albert Einstein
#
# --- Quote ke-2 ---
# Jangan pernah menyerah pada impianmu. Sekecil apapun usaha yang kita lakukan, itu akan bermakna.
# - Tere Liye, Bumi
#
# --- Quote ke-3 ---
# Keberhasilan bukan tentang seberapa cepat kita mencapai tujuan, tetapi tentang seberapa konsisten kita berusaha.
# - Tere Liye, Bulan
#
# --- Quote ke-4 ---
# Jangan takut gagal. Takutlah tidak pernah mencoba sama sekali.
# - Tere Liye, Matahari
#
# --- Quote ke-5 ---
# Setiap kesulitan pasti ada hikmahnya. Percayalah bahwa Tuhan tidak akan memberikan cobaan melebihi kemampuan kita.
# - Tere Liye, Bintang
#
# --- Quote ke-6 ---
# Mimpi bukanlah sesuatu yang kita lihat saat tidur, tetapi sesuatu yang membuat kita tidak bisa tidur.
# - Tere Liye, Hafalan Shalat Delisa
#
# --- Quote ke-7 ---
# Jangan pernah meremehkan kekuatan doa dan usaha. Keduanya adalah kunci untuk mencapai segala sesuatu.
# - Tere Liye, Bidadari Bidadari Surga
#
# --- Quote ke-8 ---
# Hidup ini singkat untuk menyia-nyiakan waktu dengan hal-hal yang tidak bermakna.
# - Tere Liye, Daun Yang Jatuh Tak Pernah Membenci Angin
#
# --- Quote ke-9 ---
# Keberanian bukanlah tentang tidak merasa takut, tetapi tentang melakukan yang benar meskipun takut.
# - Tere Liye, Pulang
