# %%
nama = input("Masukkan nama: ")
url = f"https://api.genderize.io?name={nama}"
response = requests.get(url)
data = response.json()
print("nama        :",data["name"])
print("gender      :",data["gender"])
print("probabilitas:",data["probability"])
# Out:
# Masukkan nama: budiman
# nama        : budiman
# gender      : male
# probabilitas: 0.98
